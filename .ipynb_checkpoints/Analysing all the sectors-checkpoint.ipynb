# %% [markdown]
# # ETF Analaysis

# %% [markdown]
# ## Convert Everything in Piyush code to Object Oriented Programming Code

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import seaborn as sns
from scipy.stats import norm
import numpy as np

##### ETF Data Clean up ###########

class ETFDataCleanup(object):
    
    def __init__(self):
        pass

    def showNaColumns(self,df):
        s=df.isnull().sum()
        print(s[s>0])
    
    def dropNAColumns(self,df):
        return df.dropna(axis='columns')
    
    def computeDailyReturns(self,df):
        return df.pct_change().dropna()        
    
    
####### Get Data for Constituents of ETF

class ConstituentsData(ETFDataCleanup):
    
    def __init__(self,fileName=None,startdate=None,enddate=None):
        self.fileName=fileName
        self.startdate=startdate
        self.enddate=enddate
        self.constituentdata=[]
        self.constituentcloseDF=[]
        self.tickerdf=[]
        self.changeDF=[]
        self.waDF=[]
    
    def getconstituentdata(self):
        self.tickerdf = pd.read_csv(self.fileName)
        tickers=self.tickerdf['Ticker']
        self.tickerdf.set_index('Ticker',inplace=True)
        self.constituentdata =  web.DataReader(tickers,'yahoo',self.startdate,self.enddate)
        self.constituentcloseDF = self.constituentdata['Close'].iloc[:, :]
        
    def stringWeightsToFloat(self):
        self.tickerdf['Weights']=self.tickerdf['Weights'].apply(lambda x: x.replace('%','')).astype(float)
    
    def findNetAssetValue(self):
        self.waDF=self.changeDF
        for col in self.changeDF.columns:
            self.waDF[col]=self.changeDF[col]*self.tickerdf['Weights'].loc[col]
        self.waDF['NAV']=self.waDF.sum(axis=1)/100

####### Get prices of ETF        
class ETFStockPrices(ETFDataCleanup):
    
    def __init__(self,etfticker=None,startdate=None,enddate=None):
        self.etfticker=etfticker
        self.startdate=startdate
        self.enddate=enddate
        self.etfdata=[]
        self.etfchangeDF=[]

        
    def getETFTickerData(self):
        self.etfdata =  web.DataReader(self.etfticker,'yahoo',self.startdate,self.enddate)
 


class ETFArbitrage(object):

    def __init__(self,etfob,waDF):
        self.navDF=pd.merge(etfob,waDF['NAV'],left_index=True,right_index=True)
        self.navDF['Date']=self.navDF.index
        self.difDF=[]
    
    def scatterplot(self):
        plt.scatter(self.navDF['Close'],self.navDF['NAV'])
        plt.show()
        
    def scatterplot2(self):
        #change figure size for the plot
        fig_size = plt.rcParams["figure.figsize"]
        fig_size[0]=12
        fig_size[1]=6
        plt.rcParams["figure.figsize"]=fig_size

        #(XLK Change % - NAV)   vs   Time or Date whatever
        self.difDF=self.navDF['Close']-self.navDF['NAV']
        plt.scatter(self.navDF['Date'],self.difDF)
        plt.show()
    
    def histplot(self):
        plt.hist(self.difDF,bins='auto',density=True,histtype='stepfilled')
        plt.show()
        
    def distributionNCurve(self):
        self.difDF.describe()
        diffMean=self.difDF.describe()[1]
        diffStDev=self.difDF.describe()[2]
        rng=np.arange(self.difDF.describe()[3],self.difDF.describe()[7],0.001)
        dist = norm(diffMean, diffStDev)
        plt.subplot(111) # Creates a 3 row, 1 column grid of plots, and renders the following chart in slot 1.
        plt.plot(rng, dist.pdf(rng), 'r', linewidth=2)
        plt.show()

    def seaborndist(self):
        sns.distplot(self.difDF.values, hist=True, kde=True, 
             bins='auto', color = 'black', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})

# %% [markdown]
# ## Handle

# %%
def mainhandle(filename,startdate,enddate,tickeretf):
    ob=ConstituentsData(fileName=filename,startdate=startdate,enddate=enddate)
    ob.getconstituentdata()
    tickeretf='XLK'
    
    print("Tickers with NA Values")
    ob.showNaColumns(ob.constituentcloseDF)
    ob.constituentcloseDF=ob.dropNAColumns(ob.constituentcloseDF)
    print("***************")
    print("Check for NA Values again")
    ob.showNaColumns(ob.constituentcloseDF)
    ob.changeDF=ob.computeDailyReturns(ob.constituentcloseDF)
    ob.stringWeightsToFloat()
    ob.findNetAssetValue()

    print("***************")
    print("Data for Constituents")
    print(ob.waDF.head(5))

    etfob=ETFStockPrices(etfticker=tickeretf,startdate=dt.datetime(2019,1,1),enddate=dt.datetime(2020,1,22))
    etfob.getETFTickerData()
    print("Show Any Empty Values")
    etfob.showNaColumns(etfob.etfdata)
    etfob.etfchangeDF=etfob.computeDailyReturns(etfob.etfdata['Close'])

    print("***************")
    print("Data for ETF stock prices")
    print(etfob.etfchangeDF.head(5))

    print("****************")
    print("Charts")
    arbob=ETFArbitrage(etfob.etfchangeDF,ob.waDF)
    arbob.scatterplot()
    arbob.scatterplot2()
    arbob.histplot()
    arbob.distributionNCurve()
    arbob.seaborndist()

# %% [markdown]
# # SPDR Technology XLK

# %%
mainhandle('List of XLK Etf.csv',dt.datetime(2019,1,1),dt.datetime(2020,1,22),'XLK')
# Out:
# Tickers with NA Values
# Symbols
# NLOK    64
# XLNX     1
# dtype: int64
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# ***************
# Data for Constituents
# Symbols         AAPL       ACN      ADBE       ADI       ADP      ADSK  \
# Date
# 2019-01-03 -2.020037 -0.069991 -0.102299 -0.041075 -0.034728 -0.035837
# 2019-01-04  0.865739  0.079712  0.125958  0.016509  0.045832  0.034300
# 2019-01-07 -0.045140  0.007120  0.035153  0.004276 -0.006221  0.022498
# 2019-01-08  0.386600  0.051844  0.038636  0.016589  0.006784  0.005632
# 2019-01-09  0.344390  0.010311  0.030611  0.017231  0.001051  0.014081
#
# Symbols         AKAM      AMAT       AMD      ANET  ...       STX      SWKS  \
# Date                                                ...
# 2019-01-03 -0.005328 -0.051571 -0.078460 -0.009361  ... -0.014411 -0.035156
# 2019-01-04  0.006988  0.060951  0.094927  0.002588  ...  0.009759  0.015815
# 2019-01-07  0.007518  0.015846  0.068584  0.006623  ...  0.005884  0.004460
# 2019-01-08  0.004742 -0.036067  0.007263  0.003739  ... -0.000112  0.003582
# 2019-01-09  0.003113  0.037590 -0.022400  0.002243  ...  0.005621  0.012655
#
# Symbols          TEL       TXN         V      VRSN       WDC        WU  \
# Date
# 2019-01-03 -0.019421 -0.112049 -0.187751 -0.011896 -0.021830 -0.002678
# 2019-01-04  0.013641  0.085936  0.224453  0.015213  0.013554  0.002217
# 2019-01-07  0.010284  0.032723  0.093948  0.005546  0.011367 -0.000497
# 2019-01-08 -0.001715 -0.002413  0.028336  0.012396 -0.003077  0.000299
# 2019-01-09  0.010462  0.037444  0.061317 -0.002773  0.014107  0.002490
#
# Symbols         ZBRA       NAV
# Date
# 2019-01-03 -0.012581 -0.052968
# 2019-01-04  0.008707  0.044250
# 2019-01-07  0.003185  0.008795
# 2019-01-08  0.001406  0.009299
# 2019-01-09  0.005212  0.012999
#
# [5 rows x 63 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %% [markdown]
# # SPDR Financia-ETF XLF

# %%
mainhandle('holdings-XLF.csv',dt.datetime(2019,1,1),dt.datetime(2020,1,22),'XLF')
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas_datareader/base.py:270: SymbolWarning: Failed to read symbol: 'CBOE.Z', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# Tickers with NA Values
# Symbols
# CBOE.Z    267
# LNC         3
# dtype: int64
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# ***************
# Data for Constituents
# Symbols          AFL       AIG       AIZ       AJG       ALL       AMP  \
# Date
# 2019-01-03 -0.028548 -0.028546 -0.003676 -0.009953 -0.018383 -0.016425
# 2019-01-04  0.014007  0.047974  0.004644  0.013374  0.033056  0.033212
# 2019-01-07  0.006037  0.007441  0.000915 -0.001539 -0.001761  0.002856
# 2019-01-08  0.003503  0.005147  0.000279  0.002352 -0.000136  0.003901
# 2019-01-09 -0.002494  0.018906  0.001417  0.006220  0.008550  0.006425
#
# Symbols          AON       AXP       BAC       BEN  ...       TFC      TROW  \
# Date                                                ...
# 2019-01-03 -0.021894 -0.062317 -0.127404 -0.003869  ... -0.014733 -0.029693
# 2019-01-04  0.027475  0.119410  0.330171  0.006881  ...  0.057355  0.032125
# 2019-01-07 -0.003232  0.014384 -0.006216  0.001041  ...  0.017344 -0.001272
# 2019-01-08  0.006985  0.012957 -0.015551  0.001243  ...  0.005258  0.004605
# 2019-01-09  0.002116  0.004835  0.077911 -0.001854  ...  0.020503  0.003217
#
# Symbols          TRV       UNM       USB       WFC      WLTW       WRB  \
# Date
# 2019-01-03 -0.018337 -0.000962 -0.031413 -0.042250 -0.016573 -0.005137
# 2019-01-04  0.030265  0.008307  0.055387  0.158832  0.021348  0.004788
# 2019-01-07 -0.003266  0.000488 -0.010523 -0.034653  0.005827  0.000900
# 2019-01-08 -0.003966  0.000974  0.014417 -0.011251  0.005054 -0.002265
# 2019-01-09  0.007271  0.003711  0.023876  0.029314 -0.004763  0.000861
#
# Symbols         ZION       NAV
# Date
# 2019-01-03 -0.001272 -0.022784
# 2019-01-04  0.007064  0.032705
# 2019-01-07  0.000917  0.002438
# 2019-01-08  0.002096  0.000285
# 2019-01-09  0.001971  0.004772
#
# [5 rows x 65 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %% [markdown]
# # SPDR Energy-XLE

# %%
mainhandle('holdings-XLE.csv',dt.datetime(2019,1,1),dt.datetime(2020,1,22),'XLE')
# Out:
# Tickers with NA Values
# Series([], dtype: int64)
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# ***************
# Data for Constituents
# Symbols          APA       BKR       COG       COP       CVX       CXO  \
# Date
# 2019-01-03  0.002944 -0.009976 -0.003825 -0.087283 -0.384584  0.002661
# 2019-01-04  0.047815  0.075323 -0.006416  0.116399  0.416137  0.081890
# 2019-01-07  0.024555  0.040301  0.024384 -0.020248  0.260921  0.043500
# 2019-01-08  0.016944  0.043902  0.008725  0.061738 -0.087648  0.064320
# 2019-01-09  0.058243 -0.002585 -0.014005  0.152663  0.269482  0.048793
#
# Symbols          DVN       EOG      FANG       FTI  ...       OKE       OXY  \
# Date                                                ...
# 2019-01-03  0.012421 -0.033127  0.013327  0.001536  ... -0.007455 -0.046581
# 2019-01-04  0.041518  0.205907  0.052927  0.040242  ...  0.136227  0.122240
# 2019-01-07  0.029524  0.029463  0.036475  0.029847  ...  0.054524  0.076349
# 2019-01-08  0.007337  0.050120  0.030517  0.022064  ...  0.066579  0.030056
# 2019-01-09  0.010192  0.180196  0.023668  0.020081  ...  0.045578  0.046192
#
# Symbols          PSX       PXD       SLB       VLO       WMB       XEC  \
# Date
# 2019-01-03 -0.056764  0.007588  0.045484 -0.066596  0.022966 -0.006659
# 2019-01-04  0.185892  0.080214  0.167625  0.140122  0.112667  0.023984
# 2019-01-07  0.028435  0.051555  0.116869  0.003843  0.069045  0.010571
# 2019-01-08 -0.003586 -0.001998  0.052651  0.012959  0.080795  0.007740
# 2019-01-09  0.026918  0.060167  0.059285 -0.003348  0.030511  0.009112
#
# Symbols          XOM       NAV
# Date
# 2019-01-03 -0.346994 -0.010758
# 2019-01-04  0.833255  0.036368
# 2019-01-07  0.117525  0.013685
# 2019-01-08  0.164319  0.008422
# 2019-01-09  0.119211  0.014929
#
# [5 rows x 29 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %% [markdown]
# # SPDR Industrital ETF - XLI

# %%
mainhandle('holdings-XLI.csv',dt.datetime(2019,1,1),dt.datetime(2020,1,22),'XLI')
# Out:
# Tickers with NA Values
# Symbols
# SNA    4
# dtype: int64
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# ***************
# Data for Constituents
# Symbols          AAL       ALK      ALLE       AME       AOS      ARNC  \
# Date
# 2019-01-03 -0.032038 -0.018238 -0.008114 -0.026173 -0.006039 -0.003152
# 2019-01-04  0.028323  0.010674 -0.001084  0.034796  0.010019  0.012941
# 2019-01-07  0.012213  0.000660  0.005011 -0.001487  0.004476  0.010680
# 2019-01-08 -0.006917  0.002909  0.006633  0.013541  0.006123  0.001391
# 2019-01-09  0.013263  0.008325  0.005363  0.006139  0.003478  0.001156
#
# Symbols           BA       CAT      CHRW       CMI  ...       UAL       UNP  \
# Date                                                ...
# 2019-01-03 -0.277489 -0.120613 -0.015857 -0.020585  ... -0.035752 -0.192111
# 2019-01-04  0.362215  0.171041  0.014904  0.043194  ...  0.024120  0.199886
# 2019-01-07  0.021918  0.001954  0.002080  0.005117  ...  0.004790  0.032393
# 2019-01-08  0.263458  0.037590  0.003467  0.002736  ... -0.007353  0.452932
# 2019-01-09  0.067448  0.012060  0.004928  0.002047  ...  0.012061 -0.013427
#
# Symbols          UPS       URI       UTX      VRSK       WAB        WM  \
# Date
# 2019-01-03 -0.093410 -0.015853 -0.222975 -0.033307 -0.011295 -0.005140
# 2019-01-04  0.114601  0.036762  0.171389  0.048120  0.014775  0.050463
# 2019-01-07 -0.011108  0.016666 -0.002340  0.001090 -0.005535  0.004602
# 2019-01-08  0.000338  0.008626  0.090393  0.009703  0.003534  0.026919
# 2019-01-09  0.016886  0.008744  0.019322  0.004122  0.010620 -0.009671
#
# Symbols          XYL       NAV
# Date
# 2019-01-03 -0.020226 -0.028464
# 2019-01-04  0.024893  0.037709
# 2019-01-07 -0.008726  0.007161
# 2019-01-08  0.005547  0.013869
# 2019-01-09  0.009572  0.005923
#
# [5 rows x 70 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %% [markdown]
# # SPDR Utilities ETF - XLU

# %%
mainhandle('holdings-XLU.csv',dt.datetime(2019,1,1),dt.datetime(2020,1,22),'XLU')
# Out:
# Tickers with NA Values
# Series([], dtype: int64)
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# ***************
# Data for Constituents
# Symbols          AEE       AEP       AES       ATO       AWK       CMS  \
# Date
# 2019-01-03  0.005339 -0.012516 -0.001023  0.011352  0.010370  0.003819
# 2019-01-04  0.029958  0.049443  0.048095  0.019220  0.019772  0.019060
# 2019-01-07 -0.024289 -0.029980  0.006933 -0.010961 -0.027826 -0.010491
# 2019-01-08  0.033535  0.066178  0.033515  0.019611  0.038485  0.030792
# 2019-01-09 -0.015689 -0.040676 -0.002890 -0.024564 -0.033553 -0.019532
#
# Symbols          CNP         D       DTE       DUK  ...        NI       NRG  \
# Date                                                ...
# 2019-01-03  0.008114 -0.035109  0.011387 -0.002642  ...  0.001388 -0.009635
# 2019-01-04  0.026222  0.142145  0.041577  0.061675  ...  0.020335  0.034856
# 2019-01-07  0.005446 -0.071250 -0.009183 -0.031458  ...  0.006359  0.009406
# 2019-01-08  0.027127  0.085309  0.024157  0.093897  ...  0.021682  0.015533
# 2019-01-09 -0.017423 -0.012192 -0.012837 -0.110063  ... -0.000887 -0.011475
#
# Symbols          PEG       PNW       PPL        SO       SRE       WEC  \
# Date
# 2019-01-03 -0.000657  0.011859 -0.010068  0.109762  0.020424  0.008896
# 2019-01-04  0.036147  0.014396  0.086890  0.064587  0.133189  0.024646
# 2019-01-07  0.007152 -0.002209  0.003921 -0.017311 -0.000806 -0.015169
# 2019-01-08  0.012976  0.017568  0.037198  0.220350  0.124506  0.034408
# 2019-01-09 -0.025205 -0.016218  0.000000 -0.065793 -0.043508 -0.019948
#
# Symbols          XEL       NAV
# Date
# 2019-01-03 -0.014855  0.000999
# 2019-01-04  0.036892  0.014683
# 2019-01-07 -0.016324 -0.003348
# 2019-01-08  0.043719  0.013874
# 2019-01-09 -0.030098 -0.006704
#
# [5 rows x 29 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %%
# SPDR Consumer Sta ETF - XLU
