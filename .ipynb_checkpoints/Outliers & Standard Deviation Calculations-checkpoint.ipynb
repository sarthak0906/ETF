# %% [markdown]
# # Analyzing outliers from data & Returning Dates

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import seaborn as sns
from scipy.stats import norm
from scipy import stats
import numpy as np
import os
import time
from itertools import chain
from IPython.display import display_html


##### ETF Data Clean up ###########

class ETFDataCleanup(object):
    
    def __init__(self):
        pass

    def showNaColumns(self,df):
        s=df.isnull().sum()
        print(s[s>0])
    
    def dropNAColumns(self,df):
        return df.dropna(axis='columns')
    
    def computeDailyReturns(self,df):
        return df.pct_change().dropna()        
    
    
####### Get Data for Constituents of ETF

class ConstituentsData(ETFDataCleanup):
    
    def __init__(self,fileName=None,startdate=None,enddate=None):
        self.fileName=fileName
        self.startdate=startdate
        self.enddate=enddate
        self.constituentdata=[]
        self.constituentcloseDF=[]
        self.tickerdf=[]
        self.changeDF=[]
        self.waDF=[]
    
    def getconstituentdata(self):
        self.tickerdf = pd.read_excel(self.fileName)
        tickers=self.tickerdf['Ticker']
        self.tickerdf.set_index('Ticker',inplace=True)
        self.constituentdata =  web.DataReader(tickers,'yahoo',self.startdate,self.enddate)
        self.constituentcloseDF = self.constituentdata['Close'].iloc[:, :]
        
    def stringWeightsToFloat(self):
        self.tickerdf['Weights']=self.tickerdf['Weights'].apply(lambda x: x.replace('%','')).astype(float)
    
    def findNetAssetValue(self):
        self.waDF=self.changeDF.copy()
        for col in self.changeDF.columns:
            # Divide by 100 for weights percentage eg 23.28%
            self.waDF[col]=self.changeDF[col]*self.tickerdf['Weights'].loc[col]/100
        self.waDF['NAV']=self.waDF.sum(axis=1)

####### Get prices of ETF        
class ETFStockPrices(ETFDataCleanup):
    
    def __init__(self,etfticker=None,startdate=None,enddate=None):
        self.etfticker=etfticker
        self.startdate=startdate
        self.enddate=enddate
        self.etfdata=[]
        self.etfchangeDF=[]

        
    def getETFTickerData(self):
        self.etfdata =  web.DataReader(self.etfticker,'yahoo',self.startdate,self.enddate)
 


class ETFArbitrage(object):

    def __init__(self,etfob,waDF):
        self.navDF=pd.merge(etfob,waDF['NAV'],left_index=True,right_index=True)
        self.navDF['Date']=self.navDF.index
        self.navDF['Close']=self.navDF['Close']*100
        self.navDF['NAV']=self.navDF['NAV']*100
        del self.navDF['Date']
        self.navDF['Mispricing']=(self.navDF['Close']-self.navDF['NAV'])
        self.navDF['Z-Score'] = np.abs(stats.zscore(self.navDF['Mispricing']))
    
    def scatterplot(self):
        plt.scatter(self.navDF['Close'],self.navDF['NAV'])
        
    def scatterplot2(self):
        #change figure size for the plot
        fig_size = plt.rcParams["figure.figsize"]
        fig_size[0]=12
        fig_size[1]=6
        plt.rcParams["figure.figsize"]=fig_size

        plt.scatter(self.navDF.index,self.navDF['Mispricing'])
    
    def seaborndist(self):
        sns.distplot(self.navDF['Mispricing'].values, hist=True, kde=True, 
             bins='auto', color = 'black', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})

# %% [markdown]
# # Load any ETF you want

# %%
tickeretf="XLK"

filename='ETFDailyData'+'/'+dt.datetime.now().strftime("%Y%m%d")+'/'+tickeretf+'.xls'
startdate=dt.datetime(2019,1,1)
enddate=dt.datetime.today()

ob=ConstituentsData(fileName=filename,startdate=startdate,enddate=enddate)
ob.getconstituentdata()
print(tickeretf)
print("Tickers with NA Values")
ob.showNaColumns(ob.constituentcloseDF)
ob.constituentcloseDF=ob.dropNAColumns(ob.constituentcloseDF)
print("***************")
print("Check for NA Values again")
ob.showNaColumns(ob.constituentcloseDF)
ob.changeDF=ob.computeDailyReturns(ob.constituentcloseDF)
print(ob.changeDF.tail(10))


ob.stringWeightsToFloat()
ob.findNetAssetValue()

print("***************")
print("Data for Constituents")
print(ob.waDF.head(5))

etfob=ETFStockPrices(etfticker=tickeretf,startdate=startdate,enddate=enddate)
etfob.getETFTickerData()
print("Show Any Empty Values")
etfob.showNaColumns(etfob.etfdata)
etfob.etfchangeDF=etfob.computeDailyReturns(etfob.etfdata['Close'])


print("***************")
print("Data for ETF stock prices")
print(etfob.etfchangeDF.head(5))

print("****************")
print("Charts")
arbob=ETFArbitrage(etfob.etfchangeDF,ob.waDF)
arbob.scatterplot()
plt.show()
arbob.scatterplot2()
plt.show()
arbob.seaborndist()
plt.show()
# Out:
# XLK
# Tickers with NA Values
# Symbols
# NLOK    64
# dtype: int64
# ***************
# Check for NA Values again
# Series([], dtype: int64)
# Symbols         AAPL       ACN      ADBE       ADI       ADP       ADS  \
# Date
# 2020-01-16  0.012526  0.008299  0.007115  0.013786  0.011979  0.007510
# 2020-01-17  0.011071  0.001053  0.012624  0.002854  0.011379 -0.009822
# 2020-01-21 -0.006777 -0.000239  0.000743 -0.001339 -0.003788 -0.009388
# 2020-01-22  0.003570  0.001243  0.000171  0.009304  0.012089 -0.002056
# 2020-01-23  0.004816  0.006065  0.004856  0.003654 -0.002804  0.001613
# 2020-01-24 -0.002882 -0.010015 -0.001109 -0.027222 -0.003486 -0.039356
# 2020-01-27 -0.029405 -0.009685 -0.012722 -0.045590 -0.008295 -0.016294
# 2020-01-28  0.028289  0.017865  0.022283  0.018715  0.014567  0.015902
# 2020-01-29  0.020932 -0.010845 -0.008375 -0.009448 -0.040718  0.021988
# 2020-01-30 -0.001449  0.001971  0.014446 -0.007595  0.023182 -0.022883
#
# Symbols         ADSK      AKAM      AMAT       AMD  ...      SWKS       TEL  \
# Date                                                ...
# 2020-01-16  0.008963  0.007359  0.020668  0.025129  ...  0.022172  0.006677
# 2020-01-17  0.004416 -0.005323 -0.005695  0.023307  ...  0.008774  0.006834
# 2020-01-21  0.012878 -0.003777  0.005569  0.002356  ... -0.002980 -0.006788
# 2020-01-22 -0.005668  0.006846  0.010918  0.007444  ...  0.009370 -0.005528
# 2020-01-23  0.019874  0.008787  0.000000  0.005444  ...  0.025848  0.014351
# 2020-01-24  0.002971 -0.009540 -0.029582 -0.026301  ... -0.045869 -0.019627
# 2020-01-27 -0.016668 -0.013505 -0.047581 -0.021648  ... -0.044395 -0.015854
# 2020-01-28  0.021239  0.006367  0.019306  0.025782  ...  0.024897  0.013011
# 2020-01-29 -0.001450  0.000105 -0.006147 -0.059766  ... -0.015861 -0.000306
# 2020-01-30 -0.003755 -0.002425  0.007188  0.026731  ... -0.014081 -0.022943
#
# Symbols          TXN         V      VRSN       WDC        WU      XLNX  \
# Date
# 2020-01-16  0.007664  0.005756  0.008501  0.029999  0.019209  0.025600
# 2020-01-17  0.011832  0.018661  0.002154 -0.005971  0.006524  0.015095
# 2020-01-21 -0.006378  0.012653  0.002056  0.007764 -0.016205 -0.012052
# 2020-01-22  0.018952  0.002943 -0.001632 -0.001744  0.009517 -0.003542
# 2020-01-23  0.006825 -0.006638  0.004344  0.032911  0.006164  0.011057
# 2020-01-24 -0.027784 -0.007360 -0.010557 -0.019879 -0.023423 -0.015721
# 2020-01-27 -0.032256 -0.016146 -0.014007 -0.041139  0.001845 -0.037698
# 2020-01-28  0.013696  0.005751  0.005721  0.026253  0.012523  0.016598
# 2020-01-29 -0.019916  0.009909  0.005498 -0.024119  0.000728 -0.106987
# 2020-01-30 -0.008527  0.016353  0.005704  0.002996  0.003272 -0.009766
#
# Symbols          XRX      ZBRA
# Date
# 2020-01-16  0.015523  0.024738
# 2020-01-17  0.001073 -0.004686
# 2020-01-21 -0.034825 -0.001266
# 2020-01-22  0.008049  0.005269
# 2020-01-23 -0.002478  0.002404
# 2020-01-24 -0.019597 -0.006526
# 2020-01-27 -0.013232 -0.037475
# 2020-01-28  0.049358  0.019529
# 2020-01-29 -0.001359  0.008831
# 2020-01-30  0.006806 -0.015389
#
# [10 rows x 70 columns]
# ***************
# Data for Constituents
# Symbols         AAPL       ACN      ADBE       ADI       ADP           ADS  \
# Date
# 2019-01-03 -0.020489 -0.000683 -0.001019 -0.000381 -0.000338 -1.770502e-05
# 2019-01-04  0.008781  0.000778  0.001255  0.000153  0.000446  4.737537e-05
# 2019-01-07 -0.000458  0.000069  0.000350  0.000040 -0.000061 -4.326626e-08
# 2019-01-08  0.003921  0.000506  0.000385  0.000154  0.000066  1.216524e-05
# 2019-01-09  0.003493  0.000101  0.000305  0.000160  0.000010  1.531917e-05
#
# Symbols         ADSK      AKAM      AMAT       AMD  ...       TEL       TXN  \
# Date                                                ...
# 2019-01-03 -0.000369 -0.000051 -0.000487 -0.000756  ... -0.000187 -0.001050
# 2019-01-04  0.000354  0.000067  0.000575  0.000915  ...  0.000131  0.000805
# 2019-01-07  0.000232  0.000072  0.000150  0.000661  ...  0.000099  0.000307
# 2019-01-08  0.000058  0.000045 -0.000340  0.000070  ... -0.000016 -0.000023
# 2019-01-09  0.000145  0.000030  0.000355 -0.000216  ...  0.000101  0.000351
#
# Symbols            V      VRSN       WDC        WU      XLNX       XRX  \
# Date
# 2019-01-03 -0.001917 -0.000115 -0.000205 -0.000028 -0.000128 -0.000022
# 2019-01-04  0.002292  0.000148  0.000127  0.000023  0.000157  0.000039
# 2019-01-07  0.000959  0.000054  0.000107 -0.000005  0.000090  0.000022
# 2019-01-08  0.000289  0.000120 -0.000029  0.000003 -0.000065  0.000033
# 2019-01-09  0.000626 -0.000027  0.000132  0.000026  0.000031  0.000014
#
# Symbols         ZBRA       NAV
# Date
# 2019-01-03 -0.000120 -0.053458
# 2019-01-04  0.000083  0.044765
# 2019-01-07  0.000030  0.008867
# 2019-01-08  0.000013  0.009489
# 2019-01-09  0.000050  0.013081
#
# [5 rows x 71 columns]
# Show Any Empty Values
# Series([], dtype: int64)
# ***************
# Data for ETF stock prices
# Date
# 2019-01-03   -0.050468
# 2019-01-04    0.044320
# 2019-01-07    0.008943
# 2019-01-08    0.008380
# 2019-01-09    0.012946
# Name: Close, dtype: float64
# ****************
# Charts

# %% [markdown]
# # List down all objects of 3 different classes

# %%
print("Constituents Data Objects")
print(dir(ob))

print("*************************")
print("ETF Price Object")
print(dir(etfob))

print("*************************")
print("Arbitrage Data Object")
print(dir(arbob))
# Out:
# Constituents Data Objects
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'changeDF', 'computeDailyReturns', 'constituentcloseDF', 'constituentdata', 'dropNAColumns', 'enddate', 'fileName', 'findNetAssetValue', 'getconstituentdata', 'showNaColumns', 'startdate', 'stringWeightsToFloat', 'tickerdf', 'waDF']
# *************************
# ETF Price Object
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'computeDailyReturns', 'dropNAColumns', 'enddate', 'etfchangeDF', 'etfdata', 'etfticker', 'getETFTickerData', 'showNaColumns', 'startdate']
# *************************
# Arbitrage Data Object
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'navDF', 'scatterplot', 'scatterplot2', 'seaborndist']

# %% [markdown]
# ## arbob.navDF is the ETF arbitrage dataframe which tells about
# 1) Daily Return of ETF<br>
# 2) NET Asset Value of ETF<br>
# 3) Mispricing <br>
# 4) Stocks which moved XLK ETF the most<br>

# %%
print(arbob.navDF.head(5))
# Out:
#                Close       NAV  Mispricing
# Date
# 2019-01-03 -5.046761 -5.345812    0.299051
# 2019-01-04  4.431993  4.476503   -0.044511
# 2019-01-07  0.894308  0.886728    0.007579
# 2019-01-08  0.838035  0.948878   -0.110843
# 2019-01-09  1.294552  1.308103   -0.013551

# %% [markdown]
# ## Z-Score Method

# %%
tempChangeDf=ob.changeDF.copy()*100
tempChangeDf=round(tempChangeDf,4)

# %%
negmovers=[]
posmovers=[]

for col in tempChangeDf.T:
    values=(tempChangeDf.T[col].sort_values())
    negmovers.append(dict(values[:3]))
    posmovers.append(dict(values[(len(values)-3):]))

    
arbob.navDF['Top negmovers']=negmovers
arbob.navDF['Top posmovers']=posmovers

# %%
arbob.navDF
# Out:
#                Close       NAV  Mispricing   Z-Score  \
# Date
# 2019-01-03 -5.046761 -5.345812    0.299051  3.564378
# 2019-01-04  4.431993  4.476503   -0.044511  0.331085
# 2019-01-07  0.894308  0.886728    0.007579  0.259534
# 2019-01-08  0.838035  0.948878   -0.110843  1.083196
# 2019-01-09  1.294552  1.308103   -0.013551  0.019950
# 2019-01-10  0.441778  0.416652    0.025125  0.458480
# 2019-01-11 -0.188500 -0.194391    0.005891  0.240391
# 2019-01-14 -0.928549 -0.949036    0.020487  0.405886
# 2019-01-15  1.509135  1.536709   -0.027573  0.139041
# 2019-01-16  0.093893  0.113277   -0.019384  0.046190
# 2019-01-17  0.641031  0.676769   -0.035738  0.231618
# 2019-01-18  1.522442  1.484465    0.037977  0.604192
# 2019-01-22 -1.683242 -1.839012    0.155771  1.939798
# 2019-01-23  0.342414  0.353916   -0.011502  0.043181
# 2019-01-24  0.837600  0.852408   -0.014807  0.005704
# 2019-01-25  1.415164  1.603085   -0.187921  1.957137
# 2019-01-28 -1.334745 -1.486781    0.152036  1.897457
# 2019-01-29 -1.076102 -1.140631    0.064528  0.905247
# 2019-01-30  3.108003  3.442405   -0.334402  3.618005
# 2019-01-31 -0.105501  0.050356   -0.155857  1.593581
# 2019-02-01  0.588412  0.531163    0.057249  0.822709
# 2019-02-04  1.604919  1.766311   -0.161392  1.656339
# 2019-02-05  0.841452  0.972373   -0.130921  1.310849
# 2019-02-06  0.336705  0.157614    0.179091  2.204218
# 2019-02-07 -1.371465 -1.364438   -0.007027  0.093916
# 2019-02-08  0.576922  0.441164    0.135758  1.712885
# 2019-02-11 -0.044122 -0.046740    0.002618  0.203277
# 2019-02-12  1.324311  1.334912   -0.010601  0.053394
# 2019-02-13  0.130695  0.129694    0.001001  0.184943
# 2019-02-14  0.174043  0.167709    0.006334  0.245418
# ...              ...       ...         ...       ...
# 2019-12-17 -0.232583 -0.168600   -0.063983  0.551875
# 2019-12-18 -0.011104 -0.063493    0.052390  0.767615
# 2019-12-19  0.721663  0.706847    0.014816  0.341586
# 2019-12-20  0.253523  0.571976   -0.318453  3.437173
# 2019-12-23  0.285874  0.325445   -0.039572  0.275087
# 2019-12-24  0.032890  0.041646   -0.008756  0.074314
# 2019-12-26  0.745288  0.775711   -0.030424  0.171361
# 2019-12-27 -0.010873  0.027456   -0.038329  0.260993
# 2019-12-30 -0.576658 -0.580942    0.004284  0.222169
# 2019-12-31  0.317357  0.377203   -0.059846  0.504962
# 2020-01-02  1.876297  1.747128    0.129169  1.638172
# 2020-01-03 -1.124321 -1.047034   -0.077287  0.702716
# 2020-01-06  0.238251  0.309874   -0.071623  0.638499
# 2020-01-07 -0.043216 -0.127453    0.084236  1.128708
# 2020-01-08  1.070045  1.057065    0.012980  0.320772
# 2020-01-09  1.133566  1.141966   -0.008400  0.078351
# 2020-01-10 -0.232633 -0.180641   -0.051992  0.415912
# 2020-01-13  1.250663  1.353973   -0.103310  0.997779
# 2020-01-14 -0.471053 -0.603964    0.132911  1.680607
# 2020-01-15  0.115693  0.076598    0.039095  0.616875
# 2020-01-16  1.344678  1.395335   -0.050657  0.400777
# 2020-01-17  0.673786  0.717466   -0.043680  0.321663
# 2020-01-21 -0.041187 -0.069672    0.028484  0.496567
# 2020-01-22  0.360526  0.381103   -0.020578  0.059723
# 2020-01-23  0.472133  0.495686   -0.023553  0.093457
# 2020-01-24 -0.469914 -0.412562   -0.057353  0.476695
# 2020-01-27 -2.381196 -2.343032   -0.038165  0.259131
# 2020-01-28  1.913573  1.881926    0.031648  0.532434
# 2020-01-29  0.257918  0.244716    0.013202  0.323284
# 2020-01-30  0.864372  0.878465   -0.014094  0.013794
#
#                                                 Top negmovers  \
# Date
# 2019-01-03  {'SWKS': -10.6533, 'AAPL': -9.9607, 'AMD': -9....
# 2019-01-04   {'FTNT': -0.9768, 'CDW': 0.9724, 'AVGO': 0.9828}
# 2019-01-07   {'FLIR': -0.876, 'ADP': -0.541, 'PAYX': -0.5287}
# 2019-01-08  {'AMAT': -4.0525, 'NVDA': -2.4895, 'HPE': -1.919}
# 2019-01-09    {'MSI': -2.8031, 'AMD': -2.6988, 'IT': -1.1755}
# 2019-01-10  {'AMD': -2.2288, 'MSFT': -0.6426, 'ADS': -0.5176}
# 2019-01-11    {'CDW': -1.6476, 'HPQ': -1.3973, 'MSI': -1.327}
# 2019-01-14  {'WDC': -4.9213, 'QRVO': -3.941, 'MCHP': -3.7469}
# 2019-01-15     {'QCOM': -2.74, 'MU': -1.9613, 'STX': -1.1715}
# 2019-01-16  {'FISV': -3.2916, 'AMD': -3.1894, 'FTNT': -3.0...
# 2019-01-17   {'WDC': -3.595, 'FFIV': -3.3609, 'STX': -2.4925}
# 2019-01-18     {'FTNT': -2.9594, 'IT': 0.488, 'KEYS': 0.5201}
# 2019-01-22  {'MU': -5.2852, 'NVDA': -5.1998, 'LRCX': -5.1915}
# 2019-01-23  {'QCOM': -4.6417, 'TEL': -4.3785, 'ANSS': -1.4...
# 2019-01-24  {'CTXS': -6.2581, 'FFIV': -2.2238, 'CRM': -1.9...
# 2019-01-25      {'INTC': -5.4662, 'FIS': 0.2567, 'WU': 0.275}
# 2019-01-28  {'NVDA': -13.8245, 'AMD': -7.9799, 'ANET': -5....
# 2019-01-29  {'NVDA': -4.6446, 'AMD': -4.6085, 'ANET': -4.1...
# 2019-01-30  {'JNPR': -7.585, 'MXIM': -0.9458, 'GLW': -0.5931}
# 2019-01-31   {'PYPL': -3.9602, 'FISV': -2.0435, 'V': -1.8823}
# 2019-02-01  {'MSFT': -1.58, 'INTU': -0.6348, 'AVGO': -0.5368}
# 2019-02-04  {'XLNX': -1.6247, 'AMD': -1.5504, 'AMAT': -1.043}
# 2019-02-05    {'AMD': -3.3983, 'IT': -1.5707, 'STX': -0.9219}
# 2019-02-06  {'JKHY': -2.7542, 'NOW': -1.2218, 'MSFT': -1.1...
# 2019-02-07     {'ADS': -9.8343, 'BR': -6.4226, 'MU': -5.1541}
# 2019-02-08    {'QRVO': -3.0362, 'MU': -2.0315, 'WU': -1.6921}
# 2019-02-11  {'DXC': -2.8464, 'PAYC': -2.1312, 'WDC': -1.6699}
# 2019-02-12   {'FIS': -2.3373, 'AMD': -0.6098, 'DXC': -0.2826}
# 2019-02-13  {'CDNS': -1.4771, 'CRM': -1.4681, 'NOW': -1.1421}
# 2019-02-14  {'NTAP': -5.4788, 'DXC': -2.8423, 'ADP': -1.5353}
# ...                                                       ...
# 2019-12-17      {'IT': -2.8175, 'ORCL': -2.13, 'NOW': -2.005}
# 2019-12-18   {'FLT': -2.2495, 'ADI': -1.5317, 'AMD': -1.0989}
# 2019-12-19    {'FLT': -2.6686, 'HPE': -1.0685, 'AVGO': -1.02}
# 2019-12-20  {'FFIV': -3.7372, 'FTNT': -2.3829, 'IPGP': -2....
# 2019-12-23  {'FLT': -1.9773, 'ANSS': -1.2206, 'AMAT': -1.181}
# 2019-12-24  {'STX': -1.4577, 'SNPS': -1.2151, 'GLW': -1.0302}
# 2019-12-26  {'FLT': -0.8652, 'AVGO': -0.7863, 'ADS': -0.5946}
# 2019-12-27  {'MU': -1.9597, 'NTAP': -1.7434, 'IPGP': -1.5258}
# 2019-12-30  {'PAYC': -2.4062, 'WU': -2.1556, 'NVDA': -1.9209}
# 2019-12-31  {'CDNS': -0.9001, 'INTU': -0.3462, 'MCHP': -0....
# 2020-01-02    {'DXC': -2.208, 'WU': -2.2031, 'QRVO': -0.2323}
# 2020-01-03  {'DXC': -4.1621, 'IPGP': -3.1813, 'QRVO': -3.1...
# 2020-01-06  {'KLAC': -2.2504, 'AMAT': -2.1565, 'XLNX': -2....
# 2020-01-07    {'ACN': -2.159, 'INTC': -1.6686, 'FIS': -1.539}
# 2020-01-08  {'ZBRA': -3.4429, 'MU': -1.2871, 'MCHP': -1.2648}
# 2020-01-09  {'IPGP': -3.0614, 'QRVO': -0.8502, 'AVGO': -0....
# 2020-01-10  {'IPGP': -3.1295, 'AVGO': -2.2987, 'JKHY': -2....
# 2020-01-13   {'DXC': -0.5316, 'XLNX': -0.5228, 'TEL': -0.153}
# 2020-01-14  {'PAYC': -3.0193, 'NVDA': -1.8652, 'DXC': -1.519}
# 2020-01-15   {'WDC': -3.67, 'QRVO': -2.9419, 'SWKS': -2.3674}
# 2020-01-16   {'CDW': -0.2766, 'LDOS': 0.1469, 'JKHY': 0.4171}
# 2020-01-17  {'CDW': -5.0971, 'NTAP': -4.5274, 'HPE': -4.2486}
# 2020-01-21  {'XRX': -3.4825, 'NTAP': -2.9798, 'DXC': -1.7416}
# 2020-01-22  {'FFIV': -2.0438, 'QCOM': -1.6607, 'APH': -1.5...
# 2020-01-23  {'KEYS': -1.2795, 'QCOM': -1.0433, 'BR': -0.9583}
# 2020-01-24  {'SWKS': -4.5869, 'QRVO': -4.4574, 'ADS': -3.9...
# 2020-01-27  {'IPGP': -6.693, 'KLAC': -5.0669, 'AMAT': -4.7...
# 2020-01-28  {'FFIV': -5.049, 'JNPR': -4.9448, 'NTAP': -2.1...
# 2020-01-29  {'XLNX': -10.6987, 'KEYS': -6.3442, 'AMD': -5....
# 2020-01-30    {'GLW': -2.328, 'TEL': -2.2943, 'ADS': -2.2883}
#
#                                                 Top posmovers
# Date
# 2019-01-03   {'LDOS': -1.3833, 'ORCL': -0.973, 'DXC': 0.4037}
# 2019-01-04     {'ADS': 6.7679, 'AMAT': 6.8484, 'AMD': 11.437}
# 2019-01-07    {'FTNT': 4.7526, 'NVDA': 5.2941, 'AMD': 8.2632}
# 2019-01-08     {'IPGP': 3.4158, 'CDW': 3.4807, 'VRSN': 3.646}
# 2019-01-09     {'IPGP': 4.5281, 'MU': 5.0385, 'LRCX': 5.1632}
# 2019-01-10     {'GLW': 2.2574, 'QRVO': 2.3325, 'DXC': 2.4328}
# 2019-01-11    {'NVDA': 2.4788, 'AMD': 2.6849, 'QRVO': 2.9583}
# 2019-01-14     {'ADS': 0.4001, 'XRX': 0.7227, 'NVDA': 1.0818}
# 2019-01-15   {'ADBE': 3.3254, 'ANET': 3.3723, 'PAYC': 4.9771}
# 2019-01-16     {'ZBRA': 1.4002, 'TEL': 1.5132, 'IPGP': 1.938}
# 2019-01-17   {'FISV': 2.6595, 'AMAT': 2.6754, 'ZBRA': 4.0657}
# 2019-01-18       {'ANET': 4.9993, 'MU': 5.549, 'WDC': 7.4856}
# 2019-01-22     {'IT': 0.1079, 'PAYC': 0.2202, 'FISV': 0.4755}
# 2019-01-23     {'APH': 2.8089, 'FISV': 3.0694, 'IBM': 8.4639}
# 2019-01-24  {'AMAT': 10.2302, 'LRCX': 15.6965, 'XLNX': 18....
# 2019-01-25       {'MU': 6.4772, 'STX': 6.5658, 'WDC': 7.5237}
# 2019-01-28     {'KEYS': 1.7166, 'WDC': 1.9462, 'HPE': 2.0195}
# 2019-01-29   {'LDOS': 0.7357, 'GLW': 11.0672, 'XRX': 11.3992}
# 2019-01-30     {'NOW': 4.967, 'AAPL': 6.8335, 'AMD': 19.9481}
# 2019-01-31    {'NVDA': 4.6292, 'AMD': 5.7168, 'NOW': 13.4124}
# 2019-02-01         {'MU': 3.6107, 'V': 3.8071, 'WDC': 4.4677}
# 2019-02-04     {'NVDA': 3.0747, 'PAYC': 3.3875, 'IT': 3.5492}
# 2019-02-05    {'QCOM': 2.093, 'FTNT': 2.2835, 'ANET': 2.5638}
# 2019-02-06  {'MCHP': 7.2922, 'PAYC': 7.7599, 'SWKS': 11.4929}
# 2019-02-07     {'LDOS': 2.0501, 'FLT': 6.2823, 'CDW': 6.6635}
# 2019-02-08    {'PAYC': 4.6322, 'DXC': 7.1196, 'MSI': 14.1207}
# 2019-02-11     {'MCHP': 1.7732, 'CRM': 2.068, 'AKAM': 2.1166}
# 2019-02-12     {'ANET': 4.0449, 'MU': 4.7175, 'IPGP': 7.2131}
# 2019-02-13      {'FLIR': 1.6522, 'MU': 3.1683, 'GPN': 4.5393}
# 2019-02-14   {'CSCO': 1.8947, 'PAYC': 3.0741, 'ZBRA': 6.7946}
# ...                                                       ...
# 2019-12-17   {'IPGP': 2.0167, 'LRCX': 2.2234, 'KLAC': 2.2667}
# 2019-12-18     {'DXC': 1.9502, 'SWKS': 2.4492, 'LDOS': 4.534}
# 2019-12-19      {'CSCO': 2.6587, 'WDC': 2.6909, 'MU': 2.8092}
# 2019-12-20      {'AKAM': 2.7807, 'AMD': 3.082, 'WDC': 3.9816}
# 2019-12-23     {'ZBRA': 1.6793, 'WDC': 2.6019, 'AMD': 2.9672}
# 2019-12-24    {'QRVO': 0.8722, 'SWKS': 1.7746, 'AMD': 2.3757}
# 2019-12-26    {'SNPS': 1.3458, 'PAYC': 1.5417, 'AAPL': 1.984}
# 2019-12-27      {'FIS': 0.757, 'FISV': 0.9049, 'FLT': 0.9965}
# 2019-12-30     {'WDC': 0.4024, 'AAPL': 0.5935, 'GLW': 0.7642}
# 2019-12-31      {'ADS': 1.3642, 'WDC': 1.7474, 'DXC': 2.7611}
# 2020-01-02      {'WDC': 3.3874, 'XLNX': 3.9685, 'AMD': 7.065}
# 2020-01-03     {'FTNT': 1.395, 'MSI': 1.7014, 'VRSN': 2.1095}
# 2020-01-06      {'GPN': 1.936, 'PAYC': 1.9728, 'CRM': 4.3811}
# 2020-01-07      {'MCHP': 6.7097, 'WDC': 6.7698, 'MU': 8.7736}
# 2020-01-08   {'PYPL': 1.9604, 'SNPS': 2.0285, 'INTU': 2.4055}
# 2020-01-09    {'VRSN': 2.3169, 'XLNX': 2.3493, 'AMD': 2.3834}
# 2020-01-10      {'ACN': 0.7325, 'ADS': 1.1919, 'QRVO': 1.304}
# 2020-01-13   {'NVDA': 3.1352, 'PAYC': 3.4491, 'SWKS': 3.6892}
# 2020-01-14     {'IPGP': 1.5538, 'AVGO': 2.3242, 'TEL': 2.451}
# 2020-01-15        {'GPN': 1.6047, 'V': 1.9128, 'FLT': 2.3297}
# 2020-01-16     {'ANET': 2.7461, 'WDC': 2.9999, 'IPGP': 3.771}
# 2020-01-17    {'INTU': 2.1599, 'AMD': 2.3307, 'QCOM': 4.4885}
# 2020-01-21       {'INTC': 1.594, 'CRM': 1.6682, 'MU': 2.2719}
# 2020-01-22     {'FLT': 2.3538, 'IBM': 3.3915, 'INTC': 3.6003}
# 2020-01-23    {'ANET': 3.2956, 'PAYC': 3.815, 'CTXS': 7.8214}
# 2020-01-24     {'MSI': 1.4799, 'ANET': 3.473, 'INTC': 8.1333}
# 2020-01-27    {'NOW': -0.5689, 'JNPR': -0.4475, 'WU': 0.1845}
# 2020-01-28    {'QRVO': 3.2551, 'KLAC': 3.2999, 'XRX': 4.9358}
# 2020-01-29    {'MSFT': 1.5593, 'AAPL': 2.0932, 'ADS': 2.1988}
# 2020-01-30    {'MSFT': 2.8208, 'LRCX': 4.2687, 'NOW': 9.1682}
#
# [271 rows x 6 columns]

# %% [markdown]
# # Show me days with Arbitrage Opportunities of greater than 3 Standard Deviation

# %%
stdthresold=2.5

daysofarbitrage=arbob.navDF[arbob.navDF['Z-Score']>stdthresold]
daysofarbitrage
# Out:
#                Close       NAV  Mispricing   Z-Score  \
# Date
# 2019-01-03 -5.046761 -5.345812    0.299051  3.564378
# 2019-01-30  3.108003  3.442405   -0.334402  3.618005
# 2019-03-15  0.884588  1.212627   -0.328039  3.545861
# 2019-04-25 -0.025351  0.212006   -0.237357  2.517669
# 2019-06-21 -0.823204 -0.453151   -0.370053  4.022236
# 2019-07-25 -0.410872 -0.769537    0.358665  4.240310
# 2019-07-26  0.218411  0.600923   -0.382512  4.163500
# 2019-09-20 -1.473112 -1.123101   -0.350011  3.794989
# 2019-12-20  0.253523  0.571976   -0.318453  3.437173
#
#                                                 Top negmovers  \
# Date
# 2019-01-03  {'SWKS': -10.6533, 'AAPL': -9.9607, 'AMD': -9....
# 2019-01-30  {'JNPR': -7.585, 'MXIM': -0.9458, 'GLW': -0.5931}
# 2019-03-15  {'ADBE': -3.9598, 'FTNT': -1.3273, 'FLIR': -0....
# 2019-04-25  {'XLNX': -17.077, 'ADS': -6.5655, 'KEYS': -5.4...
# 2019-06-21    {'AMD': -3.0323, 'MU': -2.6354, 'XLNX': -2.283}
# 2019-07-25  {'CTXS': -5.6096, 'PYPL': -5.0948, 'ANET': -4....
# 2019-07-26  {'XLNX': -5.3452, 'ADSK': -1.1358, 'INTC': -1....
# 2019-09-20  {'XLNX': -6.823, 'WDC': -3.1445, 'IPGP': -2.8968}
# 2019-12-20  {'FFIV': -3.7372, 'FTNT': -2.3829, 'IPGP': -2....
#
#                                                Top posmovers
# Date
# 2019-01-03  {'LDOS': -1.3833, 'ORCL': -0.973, 'DXC': 0.4037}
# 2019-01-30    {'NOW': 4.967, 'AAPL': 6.8335, 'AMD': 19.9481}
# 2019-03-15  {'NTAP': 3.5291, 'AMAT': 3.7503, 'AVGO': 8.2364}
# 2019-04-25   {'MSFT': 3.3117, 'LRCX': 4.9325, 'NOW': 7.4124}
# 2019-06-21   {'FFIV': 1.012, 'IPGP': 1.2931, 'ANET': 1.8735}
# 2019-07-25    {'FIS': 1.8137, 'GPN': 2.1249, 'FISV': 2.3256}
# 2019-07-26   {'GPN': 2.6069, 'FFIV': 4.1438, 'FISV': 6.1644}
# 2019-09-20     {'CRM': 1.0417, 'QRVO': 1.0507, 'IT': 2.5048}
# 2019-12-20     {'AKAM': 2.7807, 'AMD': 3.082, 'WDC': 3.9816}

# %% [markdown]
# ## Stocks Returns, Volume & Volume Weighted Returns Standard Deviation

# %%
# Good Function
class ZscoreAnlysByAttr():

    def __init__(self,data,zthresh,colname):
        self.data=data
        self.data.name=self.data.name+' '+colname
        self.zthresh=zthresh
        
    def getMispricedData(self):
        self.df=self.data.to_frame()
        self.df['Z-Score']=np.abs(stats.zscore(self.df.values.tolist()))
        self.requiredDF=self.df[self.df['Z-Score']>self.zthresh]
        return self.requiredDF

def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
ticker ='AAPL'
weightedMovement=ob.changeDF[ticker]*ob.constituentdata['Volume'][ticker]
weightedMovement=weightedMovement.dropna()

stockVolumeStd=ZscoreAnlysByAttr(ob.constituentdata['Volume'][ticker],stdthresold,'Volume').getMispricedData()
stockReturnStd=ZscoreAnlysByAttr(ob.changeDF[ticker]*100,stdthresold,'Return').getMispricedData()
stockweightedmovement=ZscoreAnlysByAttr(weightedMovement,stdthresold,'Volume Weighted Return').getMispricedData()

# %%
display_side_by_side(stockVolumeStd,stockReturnStd,stockweightedmovement)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAPL Volume</th>
#       <th>Z-Score</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2019-01-03</th>
#       <td>91312200.0</td>
#       <td>5.884957</td>
#     </tr>
#     <tr>
#       <th>2019-01-04</th>
#       <td>58607100.0</td>
#       <td>2.821806</td>
#     </tr>
#     <tr>
#       <th>2019-01-30</th>
#       <td>61109800.0</td>
#       <td>3.056208</td>
#     </tr>
#     <tr>
#       <th>2019-05-01</th>
#       <td>64827300.0</td>
#       <td>3.404388</td>
#     </tr>
#     <tr>
#       <th>2019-05-13</th>
#       <td>57430600.0</td>
#       <td>2.711616</td>
#     </tr>
#     <tr>
#       <th>2019-07-31</th>
#       <td>68892300.0</td>
#       <td>3.785115</td>
#     </tr>
#     <tr>
#       <th>2019-09-20</th>
#       <td>55413100.0</td>
#       <td>2.522657</td>
#     </tr>
#     <tr>
#       <th>2019-12-20</th>
#       <td>68994500.0</td>
#       <td>3.794687</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAPL Return</th>
#       <th>Z-Score</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2019-01-03</th>
#       <td>-9.960737</td>
#       <td>6.263757</td>
#     </tr>
#     <tr>
#       <th>2019-01-30</th>
#       <td>6.833468</td>
#       <td>4.009578</td>
#     </tr>
#     <tr>
#       <th>2019-05-01</th>
#       <td>4.908559</td>
#       <td>2.832075</td>
#     </tr>
#     <tr>
#       <th>2019-05-13</th>
#       <td>-5.811944</td>
#       <td>3.725861</td>
#     </tr>
#     <tr>
#       <th>2019-08-05</th>
#       <td>-5.234785</td>
#       <td>3.372802</td>
#     </tr>
#     <tr>
#       <th>2019-08-23</th>
#       <td>-4.622050</td>
#       <td>2.997980</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AAPL Volume Weighted Return</th>
#       <th>Z-Score</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2019-01-03</th>
#       <td>-9.095368e+06</td>
#       <td>10.774138</td>
#     </tr>
#     <tr>
#       <th>2019-01-04</th>
#       <td>2.501896e+06</td>
#       <td>2.878153</td>
#     </tr>
#     <tr>
#       <th>2019-01-30</th>
#       <td>4.175918e+06</td>
#       <td>4.848811</td>
#     </tr>
#     <tr>
#       <th>2019-05-01</th>
#       <td>3.182087e+06</td>
#       <td>3.678873</td>
#     </tr>
#     <tr>
#       <th>2019-05-13</th>
#       <td>-3.337835e+06</td>
#       <td>3.996373</td>
#     </tr>
#     <tr>
#       <th>2019-08-05</th>
#       <td>-2.742661e+06</td>
#       <td>3.295735</td>
#     </tr>
#     <tr>
#       <th>2019-08-23</th>
#       <td>-2.163951e+06</td>
#       <td>2.614479</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
daysofarbitrage
# Out:
#                Close       NAV  Mispricing   Z-Score  \
# Date
# 2019-01-03 -5.046761 -5.345812    0.299051  3.564378
# 2019-01-30  3.108003  3.442405   -0.334402  3.618005
# 2019-03-15  0.884588  1.212627   -0.328039  3.545861
# 2019-04-25 -0.025351  0.212006   -0.237357  2.517669
# 2019-06-21 -0.823204 -0.453151   -0.370053  4.022236
# 2019-07-25 -0.410872 -0.769537    0.358665  4.240310
# 2019-07-26  0.218411  0.600923   -0.382512  4.163500
# 2019-09-20 -1.473112 -1.123101   -0.350011  3.794989
# 2019-12-20  0.253523  0.571976   -0.318453  3.437173
#
#                                                 Top negmovers  \
# Date
# 2019-01-03  {'SWKS': -10.6533, 'AAPL': -9.9607, 'AMD': -9....
# 2019-01-30  {'JNPR': -7.585, 'MXIM': -0.9458, 'GLW': -0.5931}
# 2019-03-15  {'ADBE': -3.9598, 'FTNT': -1.3273, 'FLIR': -0....
# 2019-04-25  {'XLNX': -17.077, 'ADS': -6.5655, 'KEYS': -5.4...
# 2019-06-21    {'AMD': -3.0323, 'MU': -2.6354, 'XLNX': -2.283}
# 2019-07-25  {'CTXS': -5.6096, 'PYPL': -5.0948, 'ANET': -4....
# 2019-07-26  {'XLNX': -5.3452, 'ADSK': -1.1358, 'INTC': -1....
# 2019-09-20  {'XLNX': -6.823, 'WDC': -3.1445, 'IPGP': -2.8968}
# 2019-12-20  {'FFIV': -3.7372, 'FTNT': -2.3829, 'IPGP': -2....
#
#                                                Top posmovers
# Date
# 2019-01-03  {'LDOS': -1.3833, 'ORCL': -0.973, 'DXC': 0.4037}
# 2019-01-30    {'NOW': 4.967, 'AAPL': 6.8335, 'AMD': 19.9481}
# 2019-03-15  {'NTAP': 3.5291, 'AMAT': 3.7503, 'AVGO': 8.2364}
# 2019-04-25   {'MSFT': 3.3117, 'LRCX': 4.9325, 'NOW': 7.4124}
# 2019-06-21   {'FFIV': 1.012, 'IPGP': 1.2931, 'ANET': 1.8735}
# 2019-07-25    {'FIS': 1.8137, 'GPN': 2.1249, 'FISV': 2.3256}
# 2019-07-26   {'GPN': 2.6069, 'FFIV': 4.1438, 'FISV': 6.1644}
# 2019-09-20     {'CRM': 1.0417, 'QRVO': 1.0507, 'IT': 2.5048}
# 2019-12-20     {'AKAM': 2.7807, 'AMD': 3.082, 'WDC': 3.9816}

# %%
#d=[list(daysofarbitrage.index),list(stockVolumeStd.index),list(stockReturnStd.index),list(stockweightedmovement.index)]
d=[list(stockReturnStd.index),list(stockweightedmovement.index)]
set.intersection(*map(set,d))
# Out:
# {Timestamp('2019-01-03 00:00:00'),
#  Timestamp('2019-01-30 00:00:00'),
#  Timestamp('2019-05-01 00:00:00'),
#  Timestamp('2019-05-13 00:00:00'),
#  Timestamp('2019-08-05 00:00:00'),
#  Timestamp('2019-08-23 00:00:00')}

# %% [markdown]
# ### Find Intersection of Dates where values were > 3 std <br>
#  1) daysofarbitrage - When ETF Gave 3 STD away Returns<br>
#  2) stockVolumeStd - When Volume was 3 std away from normal day for Stock<br>
#  3) stockReturnStd - When Daily Returns were 3 srd away from normal days<br>
#  4) stockweightedmovement - When Daily Returns * Volume were 3 Stanadrd Deviation Away<br>

# %% [markdown]
# ### Dates for Mispricing Due to AAPL

# %% [markdown]
# ### Finding Dates for Mispricing Due to any of all Tickers

# %%
tickers=ob.constituentcloseDF.columns
DF=pd.DataFrame()
kvpairs={}
#MispriceDF.set_index('Ticker',inplace=True)
for ticker in tickers:
    weightedMovement=ob.changeDF[ticker]*ob.constituentdata['Volume'][ticker]
    weightedMovement=weightedMovement.dropna()
    stockVolumeStd=ZscoreAnlysByAttr(ob.constituentdata['Volume'][ticker],stdthresold,'Volume').getMispricedData()
    stockReturnStd=ZscoreAnlysByAttr(ob.changeDF[ticker]*100,stdthresold,'Return').getMispricedData()
    stockweightedmovement=ZscoreAnlysByAttr(weightedMovement,stdthresold,'Volume Weighted Return').getMispricedData()
    #d=[list(daysofarbitrage.index),list(stockVolumeStd.index),list(stockReturnStd.index),list(stockweightedmovement.index)]
    d=[list(stockReturnStd.index),list(stockweightedmovement.index)]
    lst=(list(set.intersection(*map(set,d))))
    kvpairs[ticker]=lst
#kvpairs
MispriceDF=pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in kvpairs.items() ]))
print(MispriceDF)
# Out:
#         AAPL        ACN       ADBE        ADI        ADP        ADS  \
# 0 2019-08-23 2019-08-14 2019-03-15 2019-01-03 2019-01-03 2019-04-15
# 1 2019-01-03 2019-01-03 2019-06-19 2019-06-04 2020-01-29 2019-08-21
# 2 2019-01-30 2019-09-10 2019-12-13 2019-01-24 2019-01-30 2019-08-16
# 3 2019-08-05 2019-03-28 2019-06-25 2019-08-05 2019-11-05 2019-02-07
# 4 2019-05-13 2019-08-05 2019-08-05 2019-06-10 2019-05-01 2019-10-24
# 5 2019-05-01 2019-10-02 2019-11-05 2019-10-23        NaT        NaT
# 6        NaT 2019-09-09 2019-06-03 2019-05-13        NaT        NaT
# 7        NaT 2019-01-04 2019-01-04        NaT        NaT        NaT
# 8        NaT        NaT        NaT        NaT        NaT        NaT
#
#         ADSK       AKAM       AMAT        AMD  ...       SWKS        TEL  \
# 0 2019-05-24 2019-08-05 2019-01-03 2019-01-03  ... 2019-11-01 2019-01-23
# 1 2019-11-27 2019-08-14 2019-11-15 2019-05-28  ... 2019-02-06 2019-04-24
# 2 2019-08-28 2019-07-31 2019-07-22 2019-08-08  ... 2019-01-03 2019-10-30
# 3        NaT        NaT 2019-01-24 2019-01-28  ... 2019-05-16 2019-01-03
# 4        NaT        NaT 2019-05-20 2019-01-30  ...        NaT        NaT
# 5        NaT        NaT 2019-10-24 2019-03-19  ...        NaT        NaT
# 6        NaT        NaT 2019-01-04 2019-07-31  ...        NaT        NaT
# 7        NaT        NaT        NaT 2019-01-04  ...        NaT        NaT
# 8        NaT        NaT        NaT        NaT  ...        NaT        NaT
#
#          TXN          V       VRSN        WDC         WU       XLNX  \
# 0 2019-10-23 2019-10-22 2019-04-26 2019-03-21 2019-11-01 2019-05-16
# 1 2019-01-24 2019-01-03 2019-01-03 2019-10-31 2019-06-04 2019-04-25
# 2 2019-01-03 2019-09-10 2019-01-08        NaT 2019-08-05 2019-01-24
# 3 2019-07-24 2019-02-01 2019-08-05        NaT 2019-08-02 2020-01-29
# 4        NaT 2019-08-05 2019-10-02        NaT        NaT        NaT
# 5        NaT 2019-01-04 2019-01-04        NaT        NaT        NaT
# 6        NaT        NaT        NaT        NaT        NaT        NaT
# 7        NaT        NaT        NaT        NaT        NaT        NaT
# 8        NaT        NaT        NaT        NaT        NaT        NaT
#
#          XRX       ZBRA
# 0 2019-01-29 2019-10-29
# 1 2019-10-29 2019-07-30
# 2        NaT 2019-07-18
# 3        NaT 2019-04-30
# 4        NaT 2019-02-14
# 5        NaT 2019-05-13
# 6        NaT 2019-07-11
# 7        NaT        NaT
# 8        NaT        NaT
#
# [9 rows x 70 columns]

# %% [markdown]
# ### Dropping Tickers with all NA values

# %%
MispriceDF.dropna(axis='columns',how='all').T
# Out:
#               0          1          2          3          4          5  \
# AAPL 2019-08-23 2019-01-03 2019-01-30 2019-08-05 2019-05-13 2019-05-01
# ACN  2019-08-14 2019-01-03 2019-09-10 2019-03-28 2019-08-05 2019-10-02
# ADBE 2019-03-15 2019-06-19 2019-12-13 2019-06-25 2019-08-05 2019-11-05
# ADI  2019-01-03 2019-06-04 2019-01-24 2019-08-05 2019-06-10 2019-10-23
# ADP  2019-01-03 2020-01-29 2019-01-30 2019-11-05 2019-05-01        NaT
# ADS  2019-04-15 2019-08-21 2019-08-16 2019-02-07 2019-10-24        NaT
# ADSK 2019-05-24 2019-11-27 2019-08-28        NaT        NaT        NaT
# AKAM 2019-08-05 2019-08-14 2019-07-31        NaT        NaT        NaT
# AMAT 2019-01-03 2019-11-15 2019-07-22 2019-01-24 2019-05-20 2019-10-24
# AMD  2019-01-03 2019-05-28 2019-08-08 2019-01-28 2019-01-30 2019-03-19
# ANET 2019-05-03 2019-11-01        NaT        NaT        NaT        NaT
# ANSS 2019-08-14 2019-01-03 2019-08-08 2019-08-06 2019-01-04        NaT
# APH  2019-01-03 2019-07-24        NaT        NaT        NaT        NaT
# AVGO 2019-06-14 2019-03-15 2019-05-20 2019-01-03        NaT        NaT
# BR   2019-02-07 2019-08-05 2019-11-06        NaT        NaT        NaT
# CDNS 2019-02-20 2019-08-05 2019-05-20 2019-10-22        NaT        NaT
# CDW  2019-02-07 2020-01-17 2019-09-18        NaT        NaT        NaT
# CRM  2019-06-10 2019-06-05        NaT        NaT        NaT        NaT
# CSCO 2019-05-16 2019-08-15 2019-11-14        NaT        NaT        NaT
# CTSH 2019-05-03 2019-05-02        NaT        NaT        NaT        NaT
# CTXS 2020-01-23 2019-07-25 2019-03-08 2019-01-24        NaT        NaT
# DXC  2019-11-12 2019-09-12 2019-08-09        NaT        NaT        NaT
# FFIV 2019-06-14 2019-07-26 2020-01-28 2019-03-12 2019-10-24        NaT
# FIS  2019-03-21 2019-08-06 2019-04-30 2019-08-05 2019-08-15        NaT
# FISV 2019-07-26 2019-01-18        NaT        NaT        NaT        NaT
# FLIR 2019-10-31 2019-07-24 2019-08-05 2019-04-24 2019-07-25        NaT
# FLT  2019-08-05 2019-02-07 2019-08-07 2019-05-08        NaT        NaT
# FTNT 2019-11-01 2019-08-02 2019-05-03 2019-05-23 2019-08-05        NaT
# GLW  2019-01-03 2019-07-30 2019-01-29 2019-09-17 2019-04-30        NaT
# GPN  2019-02-13 2019-10-22 2019-05-24 2019-09-10 2019-08-05 2019-06-03
# ...         ...        ...        ...        ...        ...        ...
# KLAC 2019-11-21 2019-07-18 2019-05-07 2019-01-24 2019-08-06 2019-08-05
# LDOS 2019-08-08 2019-04-30        NaT        NaT        NaT        NaT
# LRCX 2019-01-24 2019-10-24        NaT        NaT        NaT        NaT
# MA   2019-10-22 2019-01-03 2019-09-10 2019-08-05 2019-06-03 2019-01-04
# MCHP 2019-01-03 2019-02-06 2020-01-07 2019-01-24 2019-05-13        NaT
# MSFT 2019-08-14 2019-08-23 2019-01-03 2019-01-30 2019-06-25 2019-08-05
# MSI  2019-02-08        NaT        NaT        NaT        NaT        NaT
# MU   2019-03-21 2020-01-07 2019-06-26 2019-09-27        NaT        NaT
# MXIM 2019-08-23 2019-01-03 2019-01-24 2019-07-31 2019-05-13 2019-01-04
# NOW  2020-01-30 2019-10-16 2019-01-31 2019-04-25 2019-10-24        NaT
# NTAP 2019-05-23 2019-08-02        NaT        NaT        NaT        NaT
# NVDA 2019-08-16 2019-01-28        NaT        NaT        NaT        NaT
# ORCL 2019-01-04 2019-09-12 2019-06-20        NaT        NaT        NaT
# PAYC 2019-11-20 2019-02-06 2019-09-10 2019-08-05 2019-09-09 2019-06-03
# PAYX 2019-06-26 2019-07-31 2019-08-05 2019-05-01 2019-01-04        NaT
# PYPL 2019-07-25 2019-01-31 2019-10-24        NaT        NaT        NaT
# QCOM 2019-04-17 2019-05-22 2019-04-16        NaT        NaT        NaT
# QRVO 2019-11-01        NaT        NaT        NaT        NaT        NaT
# SNPS 2019-06-04 2019-08-22 2019-09-10 2019-12-02 2019-05-20        NaT
# STX  2019-01-03 2019-03-21 2019-09-19 2019-01-24 2019-01-25 2019-04-30
# SWKS 2019-11-01 2019-02-06 2019-01-03 2019-05-16        NaT        NaT
# TEL  2019-01-23 2019-04-24 2019-10-30 2019-01-03        NaT        NaT
# TXN  2019-10-23 2019-01-24 2019-01-03 2019-07-24        NaT        NaT
# V    2019-10-22 2019-01-03 2019-09-10 2019-02-01 2019-08-05 2019-01-04
# VRSN 2019-04-26 2019-01-03 2019-01-08 2019-08-05 2019-10-02 2019-01-04
# WDC  2019-03-21 2019-10-31        NaT        NaT        NaT        NaT
# WU   2019-11-01 2019-06-04 2019-08-05 2019-08-02        NaT        NaT
# XLNX 2019-05-16 2019-04-25 2019-01-24 2020-01-29        NaT        NaT
# XRX  2019-01-29 2019-10-29        NaT        NaT        NaT        NaT
# ZBRA 2019-10-29 2019-07-30 2019-07-18 2019-04-30 2019-02-14 2019-05-13
#
#               6          7          8
# AAPL        NaT        NaT        NaT
# ACN  2019-09-09 2019-01-04        NaT
# ADBE 2019-06-03 2019-01-04        NaT
# ADI  2019-05-13        NaT        NaT
# ADP         NaT        NaT        NaT
# ADS         NaT        NaT        NaT
# ADSK        NaT        NaT        NaT
# AKAM        NaT        NaT        NaT
# AMAT 2019-01-04        NaT        NaT
# AMD  2019-07-31 2019-01-04        NaT
# ANET        NaT        NaT        NaT
# ANSS        NaT        NaT        NaT
# APH         NaT        NaT        NaT
# AVGO        NaT        NaT        NaT
# BR          NaT        NaT        NaT
# CDNS        NaT        NaT        NaT
# CDW         NaT        NaT        NaT
# CRM         NaT        NaT        NaT
# CSCO        NaT        NaT        NaT
# CTSH        NaT        NaT        NaT
# CTXS        NaT        NaT        NaT
# DXC         NaT        NaT        NaT
# FFIV        NaT        NaT        NaT
# FIS         NaT        NaT        NaT
# FISV        NaT        NaT        NaT
# FLIR        NaT        NaT        NaT
# FLT         NaT        NaT        NaT
# FTNT        NaT        NaT        NaT
# GLW         NaT        NaT        NaT
# GPN         NaT        NaT        NaT
# ...         ...        ...        ...
# KLAC 2019-10-24        NaT        NaT
# LDOS        NaT        NaT        NaT
# LRCX        NaT        NaT        NaT
# MA          NaT        NaT        NaT
# MCHP        NaT        NaT        NaT
# MSFT 2019-05-13 2019-06-03 2019-01-04
# MSI         NaT        NaT        NaT
# MU          NaT        NaT        NaT
# MXIM        NaT        NaT        NaT
# NOW         NaT        NaT        NaT
# NTAP        NaT        NaT        NaT
# NVDA        NaT        NaT        NaT
# ORCL        NaT        NaT        NaT
# PAYC        NaT        NaT        NaT
# PAYX        NaT        NaT        NaT
# PYPL        NaT        NaT        NaT
# QCOM        NaT        NaT        NaT
# QRVO        NaT        NaT        NaT
# SNPS        NaT        NaT        NaT
# STX  2019-05-13        NaT        NaT
# SWKS        NaT        NaT        NaT
# TEL         NaT        NaT        NaT
# TXN         NaT        NaT        NaT
# V           NaT        NaT        NaT
# VRSN        NaT        NaT        NaT
# WDC         NaT        NaT        NaT
# WU          NaT        NaT        NaT
# XLNX        NaT        NaT        NaT
# XRX         NaT        NaT        NaT
# ZBRA 2019-07-11        NaT        NaT
#
# [70 rows x 9 columns]

# %%
constituentsdata=ob.tickerdf
constituentsdata['Ticker']=constituentsdata.index
constituentsdata=constituentsdata[['Ticker','Company Name','Weights','Last','%Change','Volume']]
constituentsdata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-a61498ecaef2> in <module>
#       1 constituentsdata=ob.tickerdf
#       2 constituentsdata['Ticker']=constituentsdata.index
# ----> 3 constituentsdata=constituentsdata[['Tciker','Company Name','Weights','Last','%Change','Volume']]
#       4 constituentsdata
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2922                 key = list(key)
#    2923             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2924                                                    raise_missing=True)
#    2925
#    2926         # take() does not accept boolean indexers
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['Tciker'] not in index"
