# %%
import requests
from datetime import datetime
import json
import time
import pandas as pd

# %%
class PolgonData(object):

    def __init__(self):
        self.params=params = (('apiKey', 'M_PKVL_rqHZI7VM9ZYO_hwPiConz5rIklx893F'),)

    def PolygonLastTrades(self,symbol):
        # Make use of Tickers
        requesturl='https://api.polygon.io/v1/last/stocks/'+symbol
        response = requests.get(requesturl, params=self.params)
        return json.loads(response.text)

    def PolygonHistoricTrades(self, date=None, symbol=None,startTS=None,endTS=None,limitresult=10):
        requesturl='https://api.polygon.io/v2/ticks/stocks/nbbo/'+symbol+'/'+date+'?timestamp='+startTS+'&timestampLimit='+'1581695521575883997'+'&limit='+limitresult
        print(requesturl)
        response = requests.get(requesturl, params=self.params)
        return json.loads(response.text)
    
    def PolygonAggregdateData(self):
        # Make use of Tickers, Date and Limit
        requesturl='https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/minute/2020-02-14/2020-02-15'
        response = requests.get(requesturl, params=self.params)
        return json.loads(response.text)

# %%
from datetime import datetime

class DateTimeManipulation(object):
    
    def __init__(self,date=None):
        self.date=date

    # Returns timestamp with milliseconds
    def unix_time_millis(self,dt):
        epoch = datetime.utcfromtimestamp(0)
        tsDate=(dt - epoch).total_seconds() * 1000.0
        tsDate=str(int(tsDate))+'000000'
        return tsDate

    def convertStringDateToTS(self,starttime='9:30:00',endtime='4:00:00'):
        marketOpenTSStr = self.date +' '+ starttime
        marketCloseTSStr = self.date +' ' + endtime
        
        marketTimeStamps={}
        print(marketOpenTSStr)
        print(marketCloseTSStr)
        marketTimeStamps['marketOpenTS']=self.unix_time_millis(datetime.strptime(marketOpenTSStr,'%Y-%m-%d %H:%M:%S'))
        marketTimeStamps['marketCloseTS']=self.unix_time_millis(datetime.strptime(marketCloseTSStr,'%Y-%m-%d %H:%M:%S'))
        return marketTimeStamps
    
    def getHumanTime(self,ts):
        s, ms = divmod(ts, 1000000000)  
        return time.gmtime(s),ms
        #print('{}.{:03d}'.format(time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(s)), ms))

# %% [markdown]
# # Process the ticker data
#
# XLK: Technology Select Sector SPDR Fund <br>
# Inception Date: 1998-12-16 <br>
# Fund Holdings as of: 2020-02-14 <br>
# "Total Assets Under Management (in thousands):	28798933" <br>
# Shares Outstanding: 282406000 <br>
# Expense Ratio: 0.13% <br>
# Tracks This Index: Technology Select Sector Index <br>
# ETFdb.com Category: Technology Equities <br>
# Issuer: State Street SPDR <br>
# Structure: ETF <br>
# ETF Home Page: https://etfdb.com/etf/XLK <br>

# %%
date='2020-02-14'
starttime='9:30:00'
endtime='4:00:00'

data=pd.read_csv("XLK-holdings20200217.csv")
symbols=list(data['Symbol'].values)+['XL']

# Create an object of date when we need and time between which we need data
datetimeObj=DateTimeManipulation(date)
marketTimeStamps=datetimeObj.convertStringDateToTS(starttime=starttime,endtime=endtime)

tickHistData={}
for symbol in symbols:
    data=PolgonData().PolygonHistoricTrades(date=date,symbol=symbol,startTS=str(marketTimeStamps['marketOpenTS']),endTS=str(marketTimeStamps['marketCloseTS']),limitresult=str(5000))
    tickHistData[symbol]=data
    print(data['ticker'])
    print(data['results'][-1]['t'])
    print(datetimeObj.getHumanTime(data['results'][-1]['t']))
# Out:
# https://api.polygon.io/v2/ticks/stocks/nbbo/MSFT/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MSFT
# 1581690671721003690
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=31, tm_sec=11, tm_wday=4, tm_yday=45, tm_isdst=0), 721003690)
# https://api.polygon.io/v2/ticks/stocks/nbbo/AAPL/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# AAPL
# 1581690948012539374
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=35, tm_sec=48, tm_wday=4, tm_yday=45, tm_isdst=0), 12539374)
# https://api.polygon.io/v2/ticks/stocks/nbbo/V/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# V
# 1581691104094531832
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=38, tm_sec=24, tm_wday=4, tm_yday=45, tm_isdst=0), 94531832)
# https://api.polygon.io/v2/ticks/stocks/nbbo/MA/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MA
# 1581691807175817822
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=50, tm_sec=7, tm_wday=4, tm_yday=45, tm_isdst=0), 175817822)
# https://api.polygon.io/v2/ticks/stocks/nbbo/INTC/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# INTC
# 1581691029617508098
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=37, tm_sec=9, tm_wday=4, tm_yday=45, tm_isdst=0), 617508098)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CSCO/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CSCO
# 1581690762337236598
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=32, tm_sec=42, tm_wday=4, tm_yday=45, tm_isdst=0), 337236598)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ADBE/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ADBE
# 1581692532512535071
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=2, tm_sec=12, tm_wday=4, tm_yday=45, tm_isdst=0), 512535071)
# https://api.polygon.io/v2/ticks/stocks/nbbo/NVDA/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# NVDA
# 1581690601722703223
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=30, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 722703223)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CRM/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CRM
# 1581691602913548264
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=46, tm_sec=42, tm_wday=4, tm_yday=45, tm_isdst=0), 913548264)
# https://api.polygon.io/v2/ticks/stocks/nbbo/PYPL/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# PYPL
# 1581691007228399957
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=36, tm_sec=47, tm_wday=4, tm_yday=45, tm_isdst=0), 228399957)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ACN/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ACN
# 1581693808960914168
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=23, tm_sec=28, tm_wday=4, tm_yday=45, tm_isdst=0), 960914168)
# https://api.polygon.io/v2/ticks/stocks/nbbo/IBM/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# IBM
# 1581691948697159717
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=52, tm_sec=28, tm_wday=4, tm_yday=45, tm_isdst=0), 697159717)
# https://api.polygon.io/v2/ticks/stocks/nbbo/AVGO/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# AVGO
# 1581692976481257213
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=9, tm_sec=36, tm_wday=4, tm_yday=45, tm_isdst=0), 481257213)
# https://api.polygon.io/v2/ticks/stocks/nbbo/TXN/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# TXN
# 1581691683940358513
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=48, tm_sec=3, tm_wday=4, tm_yday=45, tm_isdst=0), 940358513)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ORCL/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ORCL
# 1581691508789800820
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=45, tm_sec=8, tm_wday=4, tm_yday=45, tm_isdst=0), 789800820)
# https://api.polygon.io/v2/ticks/stocks/nbbo/QCOM/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# QCOM
# 1581691092476876219
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=38, tm_sec=12, tm_wday=4, tm_yday=45, tm_isdst=0), 476876219)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FIS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FIS
# 1581691462946453258
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=44, tm_sec=22, tm_wday=4, tm_yday=45, tm_isdst=0), 946453258)
# https://api.polygon.io/v2/ticks/stocks/nbbo/INTU/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# INTU
# 1581693329924454312
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=15, tm_sec=29, tm_wday=4, tm_yday=45, tm_isdst=0), 924454312)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ADP/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ADP
# 1581693363635496934
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=16, tm_sec=3, tm_wday=4, tm_yday=45, tm_isdst=0), 635496934)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FISV/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FISV
# 1581693253621629400
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=14, tm_sec=13, tm_wday=4, tm_yday=45, tm_isdst=0), 621629400)
# https://api.polygon.io/v2/ticks/stocks/nbbo/NOW/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# NOW
# 1581692761833242577
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=6, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 833242577)
# https://api.polygon.io/v2/ticks/stocks/nbbo/MU/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MU
# 1581690839435896441
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=33, tm_sec=59, tm_wday=4, tm_yday=45, tm_isdst=0), 435896441)
# https://api.polygon.io/v2/ticks/stocks/nbbo/GPN/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# GPN
# 1581691798758363120
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=49, tm_sec=58, tm_wday=4, tm_yday=45, tm_isdst=0), 758363120)
# https://api.polygon.io/v2/ticks/stocks/nbbo/AMAT/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# AMAT
# 1581691071401436838
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=37, tm_sec=51, tm_wday=4, tm_yday=45, tm_isdst=0), 401436838)
# https://api.polygon.io/v2/ticks/stocks/nbbo/AMD/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# AMD
# 1581690643623203327
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=30, tm_sec=43, tm_wday=4, tm_yday=45, tm_isdst=0), 623203327)
# https://api.polygon.io/v2/ticks/stocks/nbbo/LRCX/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# LRCX
# 1581692426128822823
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=0, tm_sec=26, tm_wday=4, tm_yday=45, tm_isdst=0), 128822823)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ADSK/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ADSK
# 1581694442019952574
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=34, tm_sec=2, tm_wday=4, tm_yday=45, tm_isdst=0), 19952574)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ADI/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ADI
# 1581693190018212078
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=13, tm_sec=10, tm_wday=4, tm_yday=45, tm_isdst=0), 18212078)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CTSH/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CTSH
# 1581693657593310273
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=20, tm_sec=57, tm_wday=4, tm_yday=45, tm_isdst=0), 593310273)
# https://api.polygon.io/v2/ticks/stocks/nbbo/HPQ/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# HPQ
# 1581691330183383822
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=42, tm_sec=10, tm_wday=4, tm_yday=45, tm_isdst=0), 183383822)
# https://api.polygon.io/v2/ticks/stocks/nbbo/MSI/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MSI
# 1581695519415750056
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=59, tm_wday=4, tm_yday=45, tm_isdst=0), 415750056)
# https://api.polygon.io/v2/ticks/stocks/nbbo/TEL/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# TEL
# 1581692801448871444
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=6, tm_sec=41, tm_wday=4, tm_yday=45, tm_isdst=0), 448871444)
# https://api.polygon.io/v2/ticks/stocks/nbbo/APH/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# APH
# 1581695521232646850
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 232646850)
# https://api.polygon.io/v2/ticks/stocks/nbbo/PAYX/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# PAYX
# 1581692910676013528
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=8, tm_sec=30, tm_wday=4, tm_yday=45, tm_isdst=0), 676013528)
# https://api.polygon.io/v2/ticks/stocks/nbbo/KLAC/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# KLAC
# 1581693808104748179
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=23, tm_sec=28, tm_wday=4, tm_yday=45, tm_isdst=0), 104748179)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FLT/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FLT
# 1581694760016458778
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=39, tm_sec=20, tm_wday=4, tm_yday=45, tm_isdst=0), 16458778)
# https://api.polygon.io/v2/ticks/stocks/nbbo/MCHP/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MCHP
# 1581693703898154489
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=21, tm_sec=43, tm_wday=4, tm_yday=45, tm_isdst=0), 898154489)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ANSS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ANSS
# 1581694516315419324
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=35, tm_sec=16, tm_wday=4, tm_yday=45, tm_isdst=0), 315419324)
# https://api.polygon.io/v2/ticks/stocks/nbbo/SNPS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# SNPS
# 1581693558031980913
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=19, tm_sec=18, tm_wday=4, tm_yday=45, tm_isdst=0), 31980913)
# https://api.polygon.io/v2/ticks/stocks/nbbo/XLNX/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# XLNX
# 1581692661124997295
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=4, tm_sec=21, tm_wday=4, tm_yday=45, tm_isdst=0), 124997295)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CDNS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CDNS
# 1581694359502830694
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=32, tm_sec=39, tm_wday=4, tm_yday=45, tm_isdst=0), 502830694)
# https://api.polygon.io/v2/ticks/stocks/nbbo/GLW/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# GLW
# 1581691754717271036
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=49, tm_sec=14, tm_wday=4, tm_yday=45, tm_isdst=0), 717271036)
# https://api.polygon.io/v2/ticks/stocks/nbbo/VRSN/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# VRSN
# 1581695501117574574
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=41, tm_wday=4, tm_yday=45, tm_isdst=0), 117574574)
# https://api.polygon.io/v2/ticks/stocks/nbbo/WDC/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# WDC
# 1581691441096713228
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=44, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 96713228)
# https://api.polygon.io/v2/ticks/stocks/nbbo/SWKS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# SWKS
# 1581692476004085803
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=1, tm_sec=16, tm_wday=4, tm_yday=45, tm_isdst=0), 4085803)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CDW/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CDW
# 1581694261150962490
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=31, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 150962490)
# https://api.polygon.io/v2/ticks/stocks/nbbo/HPE/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# HPE
# 1581691863785588733
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=51, tm_sec=3, tm_wday=4, tm_yday=45, tm_isdst=0), 785588733)
# https://api.polygon.io/v2/ticks/stocks/nbbo/KEYS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# KEYS
# 1581694111597792590
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=28, tm_sec=31, tm_wday=4, tm_yday=45, tm_isdst=0), 597792590)
# https://api.polygon.io/v2/ticks/stocks/nbbo/MXIM/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# MXIM
# 1581694192621203023
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=29, tm_sec=52, tm_wday=4, tm_yday=45, tm_isdst=0), 621203023)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FTNT/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FTNT
# 1581695507524714858
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=47, tm_wday=4, tm_yday=45, tm_isdst=0), 524714858)
# https://api.polygon.io/v2/ticks/stocks/nbbo/AKAM/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# AKAM
# 1581695521575883997
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 575883997)
# https://api.polygon.io/v2/ticks/stocks/nbbo/PAYC/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# PAYC
# 1581693085945146227
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=11, tm_sec=25, tm_wday=4, tm_yday=45, tm_isdst=0), 945146227)
# https://api.polygon.io/v2/ticks/stocks/nbbo/LDOS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# LDOS
# 1581695501686494131
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=41, tm_wday=4, tm_yday=45, tm_isdst=0), 686494131)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CTXS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CTXS
# 1581695519607453116
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=59, tm_wday=4, tm_yday=45, tm_isdst=0), 607453116)
# https://api.polygon.io/v2/ticks/stocks/nbbo/BR/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# BR
# 1581695470348193044
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=10, tm_wday=4, tm_yday=45, tm_isdst=0), 348193044)
# https://api.polygon.io/v2/ticks/stocks/nbbo/IT/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# IT
# 1581695520018264428
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=0, tm_wday=4, tm_yday=45, tm_isdst=0), 18264428)
# https://api.polygon.io/v2/ticks/stocks/nbbo/JKHY/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# JKHY
# 1581695520575203950
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=0, tm_wday=4, tm_yday=45, tm_isdst=0), 575203950)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ZBRA/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ZBRA
# 1581695518173781870
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=58, tm_wday=4, tm_yday=45, tm_isdst=0), 173781870)
# https://api.polygon.io/v2/ticks/stocks/nbbo/STX/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# STX
# 1581694987028416956
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=43, tm_sec=7, tm_wday=4, tm_yday=45, tm_isdst=0), 28416956)
# https://api.polygon.io/v2/ticks/stocks/nbbo/NTAP/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# NTAP
# 1581694225166645476
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=30, tm_sec=25, tm_wday=4, tm_yday=45, tm_isdst=0), 166645476)
# https://api.polygon.io/v2/ticks/stocks/nbbo/QRVO/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# QRVO
# 1581694110388321616
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=28, tm_sec=30, tm_wday=4, tm_yday=45, tm_isdst=0), 388321616)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ANET/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ANET
# 1581692883200988731
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=8, tm_sec=3, tm_wday=4, tm_yday=45, tm_isdst=0), 200988731)
# https://api.polygon.io/v2/ticks/stocks/nbbo/NLOK/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# NLOK
# 1581691585243135082
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=46, tm_sec=25, tm_wday=4, tm_yday=45, tm_isdst=0), 243135082)
# https://api.polygon.io/v2/ticks/stocks/nbbo/WU/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# WU
# 1581691564349380725
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=46, tm_sec=4, tm_wday=4, tm_yday=45, tm_isdst=0), 349380725)
# https://api.polygon.io/v2/ticks/stocks/nbbo/JNPR/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# JNPR
# 1581691935283685019
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=14, tm_min=52, tm_sec=15, tm_wday=4, tm_yday=45, tm_isdst=0), 283685019)
# https://api.polygon.io/v2/ticks/stocks/nbbo/DXC/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# DXC
# 1581692568012446765
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=2, tm_sec=48, tm_wday=4, tm_yday=45, tm_isdst=0), 12446765)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FFIV/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FFIV
# 1581695520079502550
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=0, tm_wday=4, tm_yday=45, tm_isdst=0), 79502550)
# https://api.polygon.io/v2/ticks/stocks/nbbo/FLIR/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# FLIR
# 1581695521257085525
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=52, tm_sec=1, tm_wday=4, tm_yday=45, tm_isdst=0), 257085525)
# https://api.polygon.io/v2/ticks/stocks/nbbo/XRX/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# XRX
# 1581695406075233281
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=50, tm_sec=6, tm_wday=4, tm_yday=45, tm_isdst=0), 75233281)
# https://api.polygon.io/v2/ticks/stocks/nbbo/IPGP/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# IPGP
# 1581695512939830345
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=52, tm_wday=4, tm_yday=45, tm_isdst=0), 939830345)
# https://api.polygon.io/v2/ticks/stocks/nbbo/ADS/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# ADS
# 1581695515105653945
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=55, tm_wday=4, tm_yday=45, tm_isdst=0), 105653945)
# https://api.polygon.io/v2/ticks/stocks/nbbo/CASH/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# CASH
# 1581695501968910224
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=15, tm_min=51, tm_sec=41, tm_wday=4, tm_yday=45, tm_isdst=0), 968910224)
# https://api.polygon.io/v2/ticks/stocks/nbbo/XL/2020-02-14?timestamp=1581672600000000000&timestampLimit=1581695521575883997&limit=5000
# XL
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-b8b61ded577e> in <module>
#      15     tickHistData[symbol]=data
#      16     print(data['ticker'])
# ---> 17     print(data['results'][-1]['t'])
#      18     print(datetimeObj.getHumanTime(data['results'][-1]['t']))
#
# IndexError: list index out of range

# %%
1581672600000000000
1581652800000000000

1581695521575883997
# Out:
# (time.struct_time(tm_year=2020, tm_mon=2, tm_mday=14, tm_hour=3, tm_min=56, tm_sec=40, tm_wday=4, tm_yday=45, tm_isdst=0),
#  0)

# %%
append

# %%
ob=DateTimeManipulation()

str(ob.unix_time_millis(datetime.strptime('2020-02-14 4:00:00','%Y-%m-%d %H:%M:%S')))
# Out:
# '1.5816528e+18'

# %%
marketTimeStamps['marketOpenTS']*10^18
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-d189f5cdb39e> in <module>
# ----> 1 marketTimeStamps['marketOpenTS']*10^18
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'
